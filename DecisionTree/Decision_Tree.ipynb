# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohammed-Khubaib/ML/blob/main/DecisionTree/Decision_Tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn import tree

# %%
dataset = pd.read_csv("Logistic_Iris.csv")

# %%
x = dataset.iloc[:, [0,1,2,3]].values

# %%
y = dataset.iloc[:, 4].values

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.25, random_state=0)

# %%
sc = StandardScaler()
xtrain = sc.fit_transform(xtrain)
xtest = sc.transform(xtest)

# %%
dtree_gini = DecisionTreeClassifier(criterion = "gini", random_state = 100,max_depth=3, min_samples_leaf=5)
dtree_gini.fit(xtrain, ytrain)

# %%
y_pred1 = dtree_gini.predict(xtest)

# %%
accgini= accuracy_score(ytest,y_pred1)*100
print ("\nAccuracy using Gini Index: ", accgini)
# Out:
# Accuracy using Gini Index:  86.8421052631579

# %%
cm = confusion_matrix(ytest, y_pred1)
print ("\n\n Confusion Matrix -using Gini Index: \n", cm)
# Out:
#  Confusion Matrix -using Gini Index:
#  [[14  0  0]
#  [ 0 13  1]
#  [ 0  4  6]]

# %%
tree.plot_tree(dtree_gini , rounded = True,fontsize = 10)
# Out:
# [Text(0.6, 0.875, 'x[3] <= 0.642\ngini = 0.666\nsamples = 111\nvalue = [35, 36, 40]'),
#  Text(0.4, 0.625, 'x[3] <= -0.588\ngini = 0.514\nsamples = 72\nvalue = [35, 36, 1]'),
#  Text(0.2, 0.375, 'gini = 0.0\nsamples = 35\nvalue = [35, 0, 0]'),
#  Text(0.6, 0.375, 'x[2] <= 0.559\ngini = 0.053\nsamples = 37\nvalue = [0, 36, 1]'),
#  Text(0.4, 0.125, 'gini = 0.0\nsamples = 32\nvalue = [0, 32, 0]'),
#  Text(0.8, 0.125, 'gini = 0.32\nsamples = 5\nvalue = [0, 4, 1]'),
#  Text(0.8, 0.625, 'gini = 0.0\nsamples = 39\nvalue = [0, 0, 39]')]

# %%
# Using Entropy :
dtree_entropy = DecisionTreeClassifier(criterion = "entropy", random_state = 100, max_depth = 3, min_samples_leaf = 5)
dtree_entropy.fit(xtrain, ytrain)
y_pred2 = dtree_entropy.predict(xtest)

# %%
acc_entropy= accuracy_score(ytest,y_pred2)*100
print ("\n\nAccuracy using Entropy: ", acc_entropy)
# Out:
# Accuracy using Entropy:  86.8421052631579

# %%
cm = confusion_matrix(ytest, y_pred2)
print ("\n\n Confusion Matrix -using Entropy: \n", cm)
# Out:
#  Confusion Matrix -using Entropy:
#  [[14  0  0]
#  [ 0 13  1]
#  [ 0  4  6]]

# %%
tree.plot_tree(dtree_entropy , rounded = True,fontsize = 10)
# Out:
# [Text(0.4, 0.875, 'x[2] <= -0.71\nentropy = 1.583\nsamples = 111\nvalue = [35, 36, 40]'),
#  Text(0.2, 0.625, 'entropy = 0.0\nsamples = 35\nvalue = [35, 0, 0]'),
#  Text(0.6, 0.625, 'x[3] <= 0.642\nentropy = 0.998\nsamples = 76\nvalue = [0, 36, 40]'),
#  Text(0.4, 0.375, 'x[2] <= 0.559\nentropy = 0.179\nsamples = 37\nvalue = [0, 36, 1]'),
#  Text(0.2, 0.125, 'entropy = 0.0\nsamples = 32\nvalue = [0, 32, 0]'),
#  Text(0.6, 0.125, 'entropy = 0.722\nsamples = 5\nvalue = [0, 4, 1]'),
#  Text(0.8, 0.375, 'entropy = 0.0\nsamples = 39\nvalue = [0, 0, 39]')]
